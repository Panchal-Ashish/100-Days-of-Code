# %% [raw]
# stage 1

# %%
word_list = ["pratham","ashish","mayur","sunny","blossom","harsh","priyank","zebra","virat","rishab"]

#TODO-1 - Randomly choose a word from the word_list and assign it to a variable called chosen_word.
import random
chosen_word = random.choice(word_list)

#TODO-2 - Ask the user to guess a letter and assign their answer to a variable called guess. Make guess lowercase.
guess = input("Guess a letter: ").lower()
#TODO-3 - Check if the letter the user guessed (guess) is one of the letters in the chosen_word.
for letter in chosen_word:
    if guess == letter:
        print("Right")
    else:
        print("Wrong")
# Out:
# Guess a letter: a
# Wrong
# Wrong
# Right
# Wrong
# Wrong
# Right
# Wrong

# %% [raw]
# stage 2

# %%
#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#TODO-1: - Create an empty List called display.
#For each letter in the chosen_word, add a "_" to 'display'.
#So if the chosen_word was "apple", display should be ["_", "_", "_", "_", "_"] with 5 "_" representing each letter to guess.

display = []
for letter in chosen_word :  # alternatively# range(1,len(chosen_word) + 1)    or    0 to len(chosen_word)
    display.append("_")
print(display)

#TODO-2: - Loop through each position in the chosen_word;
#If the letter at that position matches 'guess' then reveal that letter in the display at that position.
#e.g. If the user guessed "p" and the chosen word was "apple", then display should be ["_", "p", "p", "_", "_"].

for position in range(0,len(chosen_word)):  # this gives a number (stored in position) which is later used for indexing
    letter = chosen_word[position]
    if guess == letter:
        display[position] = guess



#TODO-3: - Print 'display' and you should see the guessed letter in the correct position and every other letter replace with "_".
#Hint - Don't worry about getting the user to guess the next letter. We'll tackle that in step 3.

print(display)
# Out:
# Pssst, the solution is pratham.
# ['_', '_', '_', '_', '_', '_', '_']
# ['_', '_', 'a', '_', '_', 'a', '_']

# %% [raw]
# stage 3

# %%
#TODO-1: - Use a while loop to let the user guess again. 
#The loop should only stop once the user has guessed all the letters in the chosen_word and 'display' has no more blanks ("_"). 
#Then you can tell the user they've won.

# %% [markdown]
# # hangman art

# %%
logo = ''' 
 _                                             
| |                                            
| |__   __ _ _ __   __ _ _ __ ___   __ _ _ __  
| '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \ 
| | | | (_| | | | | (_| | | | | | | (_| | | | |
|_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
                    __/ |                      
                   |___/    '''

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']


word_list = ["pandya",
             "ashish",
             "jadeja",
             "priyank",
             "rishab",
             "ashwin",
             "muralidharan",
             "sangakkara",
             "cheteshwar",
             "ponting",
             "warner",
             "dhawan",
             "malinga",
             "williamson",
             "anderson",
             "russell",
             "shubman",
             "jayawardene",
             "dilshan",
             "krunal",
             "shakib",
             "dravid",
             "laxman",
             "pollard",
             "kallis",
             "rabada",
             "azharuddin",
             "ganguly",
             "ishant",
             "southee",
             "sharma",
             "bumrah",
             "shankar",
             "pieterson",
             "hussey",
             "hayden",
             "gilchrist",
             "zaheer",
             "rhodes",
             "sreesanth",
             "pathan",
             "harbhajan",
             "yuvraj",
             "johnson",
             "curran",
             "gambhir",
             "sehwag"]

# %% [markdown]
# # final

# %%
#TODO - Randomly choose a word from the word_list and assign it to a variable called chosen_word.
import random
chosen_word = random.choice(word_list)

#Testing code
# print(f'Pssst, the solution is {chosen_word}.')

print(logo)
print("The word consists ", len(chosen_word)," letters ")


#TODO - Create an empty List called display.
#For each letter in the chosen_word, add a "_" to 'display'.
#So if the chosen_word was "apple", display should be ["_", "_", "_", "_", "_"] with 5 "_" representing each letter to guess.
display = []
for letter in chosen_word :  # alternatively# range(1,len(chosen_word) + 1)    or    0 to len(chosen_word)
    display.append("_")
print(display)

lives = 6
print(f"you have Total {lives} lives left!")
#TODO - Ask the user to guess a letter and assign their answer to a variable called guess. Make guess lowercase.

end_of_game = False    # Method 2
    
while end_of_game == False:   #alternative  # while "_" in display: but not effective in ending game even after all lives are lost
    guess = input("Guess a letter: ").lower()
    
    if guess in display:
        print ("OOPS!!! you have already guessed this word earlier")
    



#TODO - Loop through each position in the chosen_word;
#If the letter at that position matches 'guess' then reveal that letter in the display at that position.
#e.g. If the user guessed "p" and the chosen word was "apple", then display should be ["_", "p", "p", "_", "_"].

    for position in range(0,len(chosen_word)):  # this gives a number (stored in position) which is later used for indexing
        letter = chosen_word[position]
        
        if guess == letter:
            display[position] = guess
#             print(display)
        
            if "_" not in display: 
                end_of_game = True    # to stop the game and exit while loop
                print("you win!!!")
                print(f"correct answer is : {chosen_word}")

            
    if guess not in chosen_word:
        lives = lives - 1
        print(stages[lives])
        print("the letter you guessed is not present in the word.You lose a life")
        print(f"you have {lives} more lives left!")
        if lives == 0:
            print("you lose!!!")
            print(f"correct answer is : {chosen_word}")
            end_of_game = True    # to stop the game and exit while loop

    print(display)
            



    #TODO - Print 'display' and you should see the guessed letter in the correct position and every other letter replace with "_".
# Out:
#
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# The word consists  9  letters
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# you have Total 6 lives left!
# Guess a letter: g
# ['g', '_', '_', '_', '_', '_', '_', '_', '_']
# Guess a letter: g
# OOPS!!! you have already guessed this word earlier
# ['g', '_', '_', '_', '_', '_', '_', '_', '_']
# Guess a letter: r
# ['g', '_', '_', '_', '_', 'r', '_', '_', '_']
# Guess a letter: w
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# the letter you guessed is not present in the word.You lose a life
# you have 5 more lives left!
# ['g', '_', '_', '_', '_', 'r', '_', '_', '_']
# Guess a letter: w
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# ...
