# %%
logo = """
    __  ___       __             
   / / / (_)___ _/ /_  ___  _____
  / /_/ / / __ `/ __ \/ _ \/ ___/
 / __  / / /_/ / / / /  __/ /    
/_/ ///_/\__, /_/ /_/\___/_/     
   / /  /____/_      _____  _____
  / /   / __ \ | /| / / _ \/ ___/
 / /___/ /_/ / |/ |/ /  __/ /    
/_____/\____/|__/|__/\___/_/     
"""

vs = """
 _    __    
| |  / /____
| | / / ___/
| |/ (__  ) 
|___/____(_)
"""

# %%
data = [
    {
        'name': 'Instagram',
        'follower_count': 400,
        'description': 'Social media platform',
        'country': 'United States'
    },
    {
        'name': 'Cristiano Ronaldo',
        'follower_count': 306,
        'description': 'Footballer',
        'country': 'Portugal'
    },
    {
        'name': 'Ariana Grande',
        'follower_count': 247,
        'description': 'Musician and actress',
        'country': 'United States'
    },
    {
        'name': 'Dwayne Johnson',
        'follower_count': 149,
        'description': 'Actor and professional wrestler',
        'country': 'United States'
    },
    {
        'name': 'Selena Gomez',
        'follower_count': 240,
        'description': 'Musician and actress',
        'country': 'United States'
    },
    {
        'name': 'Kylie Jenner',
        'follower_count': 244,
        'description': 'Reality TV personality and businesswoman and Self-Made Billionaire',
        'country': 'United States'
    },
    {
        'name': 'Kim Kardashian',
        'follower_count': 231,
        'description': 'Reality TV personality and businesswoman',
        'country': 'United States'
    },
    {
        'name': 'Lionel Messi',
        'follower_count': 223,
        'description': 'Footballer',
        'country': 'Argentina'
    },
    {
        'name': 'Beyoncé',
        'follower_count': 189,
        'description': 'Musician',
        'country': 'United States'
    },
    {
        'name': 'Neymar',
        'follower_count': 153,
        'description': 'Footballer',
        'country': 'Brasil'
    },
    {
        'name': 'National Geographic',
        'follower_count': 169,
        'description': 'Magazine',
        'country': 'United States'
    },
    {
        'name': 'Justin Bieber',
        'follower_count': 180,
        'description': 'Musician',
        'country': 'Canada'
    },
    {
        'name': 'Taylor Swift',
        'follower_count': 165,
        'description': 'Musician',
        'country': 'United States'
    },
    {
        'name': 'Kendall Jenner',
        'follower_count': 171,
        'description': 'Reality TV personality and Model',
        'country': 'United States'
    },
    {
        'name': 'Jennifer Lopez',
        'follower_count': 162,
        'description': 'Musician and actress',
        'country': 'United States'
    },
    {
        'name': 'Nicki Minaj',
        'follower_count': 143,
        'description': 'Musician',
        'country': 'Trinidad and Tobago'
    },
    {
        'name': 'Nike',
        'follower_count': 157,
        'description': 'Sportswear multinational',
        'country': 'United States'
    },
    {
        'name': 'Khloé Kardashian',
        'follower_count': 159,
        'description': 'Reality TV personality and businesswoman',
        'country': 'United States'
    },
    {
        'name': 'Miley Cyrus',
        'follower_count': 136,
        'description': 'Musician and actress',
        'country': 'United States'
    },
    {
        'name': 'Katy Perry',
        'follower_count': 125,
        'description': 'Musician',
        'country': 'United States'
    },
    {
        'name': 'Kourtney Kardashian',
        'follower_count': 129,
        'description': 'Reality TV personality',
        'country': 'United States'
    },
    {
        'name': 'Kevin Hart',
        'follower_count': 113,
        'description': 'Comedian and actor',
        'country': 'United States'
    },
    {
        'name': 'Ellen DeGeneres',
        'follower_count': 101,
        'description': 'Comedian',
        'country': 'United States'
    },
    {
        'name': 'Real Madrid CF',
        'follower_count': 100,
        'description': 'Football club',
        'country': 'Spain'
    },
    {
        'name': 'FC Barcelona',
        'follower_count': 97.7,
        'description': 'Football club',
        'country': 'Spain'
    },
    {
        'name': 'Demi Lovato',
        'follower_count': 108,
        'description': 'Musician and actress',
        'country': 'United States'
    },
    {
        'name': "Victoria's Secret",
        'follower_count': 69.4,
        'description': 'Lingerie brand',
        'country': 'United States'
    },
    {
        'name': 'Zendaya',
        'follower_count': 99,
        'description': 'Actress and musician',
        'country': 'United States'
    },
    {
        'name': 'Shakira',
        'follower_count': 70.2,
        'description': 'Musician',
        'country': 'Colombia'
    },
    {
        'name': 'Drake',
        'follower_count': 65,
        'description': 'Musician',
        'country': 'Canada'
    },
    {
        'name': 'Chris Brown',
        'follower_count': 85.8,
        'description': 'Musician',
        'country': 'United States'
    },
    {
        'name': 'LeBron James',
        'follower_count': 63,
        'description': 'Basketball player',
        'country': 'United States'
    },
    {
        'name': 'Vin Diesel',
        'follower_count': 71.3,
        'description': 'Actor',
        'country': 'United States'
    },
    {
        'name': 'Cardi B',
        'follower_count': 97.9,
        'description': 'Musician',
        'country': 'United States'
    },
    {
        'name': 'David Beckham',
        'follower_count': 68,
        'description': 'Footballer',
        'country': 'United Kingdom'
    },
    {
        'name': 'Billie Eilish',
        'follower_count': 61,
        'description': 'Musician',
        'country': 'United States'
    },
    {
        'name': 'Justin Timberlake',
        'follower_count': 59,
        'description': 'Musician and actor',
        'country': 'United States'
    },
    {
        'name': 'UEFA Champions League',
        'follower_count': 76,
        'description': 'Club football competition',
        'country': 'Europe'
    },
    {
        'name': 'NASA',
        'follower_count': 67.4,
        'description': 'Space agency',
        'country': 'United States'
    },
    {
        'name': 'Emma Watson',
        'follower_count': 60,
        'description': 'Actress',
        'country': 'United Kingdom'
    },
    {
        'name': 'Shawn Mendes',
        'follower_count': 60.7,
        'description': 'Musician',
        'country': 'Canada'
    },
    {
        'name': 'Virat Kohli',
        'follower_count': 131,
        'description': 'Cricketer',
        'country': 'India'
    },
    {
        'name': 'Gigi Hadid',
        'follower_count': 54,
        'description': 'Model',
        'country': 'United States'
    },
    {
        'name': 'Priyanka Chopra Jonas',
        'follower_count': 65,
        'description': 'Actress and musician',
        'country': 'India'
    },
    {
        'name': '9GAG',
        'follower_count': 57,
        'description': 'Social media platform',
        'country': 'China'
    },
    {
        'name': 'Ronaldinho',
        'follower_count': 51,
        'description': 'Footballer',
        'country': 'Brasil'
    },
    {
        'name': 'Maluma',
        'follower_count': 50,
        'description': 'Musician',
        'country': 'Colombia'
    },
    {
        'name': 'Sachin Tendulkar',
        'follower_count' : 30,
        'description':'Former Cricketer (god of cricket)',
        'country': 'India'
    },
    {
        'name': 'Camila Cabello',
        'follower_count': 53.5,
        'description': 'Musician',
        'country': 'Cuba'
    },
    {
        'name': 'NBA',
        'follower_count': 57.2,
        'description': 'Club Basketball Competition',
        'country': 'United States'
    }
]

# %% [markdown]
# # OWN code

# %%
import random
A = random.choice(data)
B = random.choice(data)
while A == B:
    B = random.choice(data)
score = 0
winner = ""

def higher_lower():
    global winner
    
    print(f"Compare A: {A['name']}, a {A['description']}, from {A['country']}")
    print(vs)
    print(f"Against B: {B['name']}, a {B['description']}, from {B['country']}")
    
    X = A['follower_count']
    Y = B['follower_count']
    if X > Y:
        winner = "A"
    elif X < Y:
        winner = "B"
        
    guess = input("Who has more Instagram followers... Type A or B: \n").upper()
    if guess == winner:
        return "WIN"
    elif guess != winner:
        return "LOSE"
    

play = True
while play:
    print(f"Your current score is {score}")
    print(logo)
    result = higher_lower()
    if result == "WIN":
        print("\nCorrect Answer")
        score += 1
        if winner == "B":
            A = B
        B = random.choice(data)
        while A == B:
            B = random.choice(data)
        
    if result == "LOSE":
        play = False
        print("\nIncorrect answer")
        print(f"your final score is {score}")
    
        

# result = higher_lower()
# print(result)
# print(score)
# Out:
# Your current score is 0
#
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: Khloé Kardashian, a Reality TV personality and businesswoman, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Gigi Hadid, a Model, from United States
# Who has more Instagram followers... Type A or B:
# a
#
# Correct Answer
# Your current score is 1
#
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: Khloé Kardashian, a Reality TV personality and businesswoman, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: National Geographic, a Magazine, from United States
# Who has more Instagram followers... Type A or B:
# a
#
# Incorrect answer
# your final score is 1

# %% [markdown]
# # Video assisted code

# %%
import random

def format_data(account):
    """ Takes the account and returns the data in printable format"""
    account_name = account['name']
    account_description = account['description']
    account_country = account['country']
    return f"{account_name}, a {account_description}, from {account_country}"

def check_answer(guess,A_followers,B_followers):
    """Takes the user guess, follower counts and returns if they got it right"""
    if A_followers > B_followers :
        return guess == "A"       # alt. if guess == "A":.... return TRUE
    elif A_followers < B_followers:
        return guess == "B"

    
score = 0
print(logo)
game_continue = True
A = random.choice(data)
B = random.choice(data)
    
while game_continue:
    # Make the game repeatable     
    # generate random account from game data 
#     A = random.choice(data)
#     B = random.choice(data)
    while A == B:
        B = random.choice(data)


    print(f"Compare A: {format_data(A)}")
    print(vs)
    print(f"Against B: {format_data(B)}")

    # ask user for guess
    guess = input("Who has more Instagram followers... Type A or B: \n").upper()

    # Check if user is correct
    ## get follower count of each account 
    A_follower_count = A['follower_count']
    B_follower_count = B['follower_count']

    ## check if user is correct using if stmt
    is_correct = check_answer(guess,A_follower_count,B_follower_count)

    # Give user a feedback on their guesses
    if is_correct:
        score += 1
        print(f"You are correct. Your current score is {score}")
        if guess == "B":
            A = B
        B = random.choice(data)
    else:
        print(f"Sorry. you are not correct. Your final score is {score}")
        game_continue = False
    # Make the game repeatable
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: Kourtney Kardashian, a Reality TV personality, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Shawn Mendes, a Musician, from Canada
# Who has more Instagram followers... Type A or B:
# a
# You are correct. Your current score is 1
# Compare A: Kourtney Kardashian, a Reality TV personality, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Ariana Grande, a Musician and actress, from United States
# Who has more Instagram followers... Type A or B:
# b
# You are correct. Your current score is 2
# Compare A: Ariana Grande, a Musician and actress, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Instagram, a Social media platform, from United States
# Who has more Instagram followers... Type A or B:
# b
# You are correct. Your current score is 3
# Compare A: Instagram, a Social media platform, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Neymar, a Footballer, from Brasil
# Who has more Instagram followers... Type A or B:
# b
# Sorry. you are not correct. Your final score is 3
