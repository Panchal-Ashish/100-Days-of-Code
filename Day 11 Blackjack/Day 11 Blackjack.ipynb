# %% [markdown]
# # starting instructions

# %%
############### Blackjack Project #####################

#Difficulty Normal 😎: Use all Hints below to complete the project.
#Difficulty Hard 🤔: Use only Hints 1, 2, 3 to complete the project.
#Difficulty Extra Hard 😭: Only use Hints 1 & 2 to complete the project.
#Difficulty Expert 🤯: Only use Hint 1 to complete the project.

############### Our Blackjack House Rules #####################

## The deck is unlimited in size. 
## There are no jokers. 
## The Jack/Queen/King all count as 10.
## The the Ace can count as 11 or 1.
## Use the following list as the deck of cards:
## cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
## The cards in the list have equal probability of being drawn.
## Cards are not removed from the deck as they are drawn.
## The computer is the dealer.

##################### Hints #####################

#Hint 1: Go to this website and try out the Blackjack game: 
#   https://games.washingtonpost.com/games/blackjack/
#Then try out the completed Blackjack project here: 
#   http://blackjack-final.appbrewery.repl.run

#Hint 2: Read this breakdown of program requirements: 
#   http://listmoz.com/view/6h34DJpvJBFVRlZfJvxF
#Then try to create your own flowchart for the program.

#Hint 3: Download and read this flow chart I've created: 
#   https://drive.google.com/uc?export=download&id=1rDkiHCrhaf9eX7u7yjM1qwSuyEk-rPnt

#Hint 4: Create a deal_card() function that uses the List below to *return* a random card.
#11 is the Ace.
#cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]

#Hint 5: Deal the user and computer 2 cards each using deal_card() and append().
#user_cards = []
#computer_cards = []

#Hint 6: Create a function called calculate_score() that takes a List of cards as input 
#and returns the score. 
#Look up the sum() function to help you do this.

#Hint 7: Inside calculate_score() check for a blackjack (a hand with only 2 cards: ace + 10) and return 0 instead of the actual score. 0 will represent a blackjack in our game.

#Hint 8: Inside calculate_score() check for an 11 (ace). If the score is already over 21, remove the 11 and replace it with a 1. You might need to look up append() and remove().

#Hint 9: Call calculate_score(). If the computer or the user has a blackjack (0) or if the user's score is over 21, then the game ends.

#Hint 10: If the game has not ended, ask the user if they want to draw another card. If yes, then use the deal_card() function to add another card to the user_cards List. If no, then the game has ended.

#Hint 11: The score will need to be rechecked with every new card drawn and the checks in Hint 9 need to be repeated until the game ends.

#Hint 12: Once the user is done, it's time to let the computer play. The computer should keep drawing cards as long as it has a score less than 17.

#Hint 13: Create a function called compare() and pass in the user_score and computer_score. If the computer and user both have the same score, then it's a draw. If the computer has a blackjack (0), then the user loses. If the user has a blackjack (0), then the user wins. If the user_score is over 21, then the user loses. If the computer_score is over 21, then the computer loses. If none of the above, then the player with the highest score wins.

#Hint 14: Ask the user if they want to restart the game. If they answer yes, clear the console and start a new game of blackjack and show the logo from art.py.

# %% [markdown]
# ## This code is written by me

# %% [markdown]
#                             ☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️☝️
# Note 1(bug 1)... it only asks the user for more cards only once
#
# Note 2... if user and computer both go above 21, user wins... making the game slightly user tilted (even if both scores above 21 are equal)

# %%
def play():  
    logo = """
    .------.            _     _            _    _            _    
    |A_  _ |.          | |   | |          | |  (_)          | |   
    |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
    | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
    |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   < 
    `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\\
          |  \/ K|                            _/ |                
          `------'                           |__/           
    """

    print(logo)    
    import random
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]

    def deal_card():
        return random.choice(cards)

    def calculate_score(list_of_cards):
        """Takes a list of cards and returns the score(sum)"""

        if (10 in list_of_cards) and (11 in list_of_cards) and len(list_of_cards) == 2:    # alt. sum(list_of_cards) == 21 and len
            return 0    # 0 represents blackjack

        score = sum(list_of_cards)
        if (11 in list_of_cards) and score > 21:
            list_of_cards.remove(11)
            list_of_cards.append(1)
            score = sum(list_of_cards)
        return score



    def winner(computer_score,user_score):
        end = False
        while not end:
            if computer_score == 0 or user_score > 21:
                end = True
                return "computer wins. you lose"
            if computer_score > 21 or user_score == 0:
                end = True
                return "You win"
            else:
                one_more = input("\nDo you want to draw another card? type 'yes' or 'no': ").lower()
                if one_more =="yes":
                    user_cards.append(deal_card())
                    user_score = calculate_score(user_cards)
                    print(f"\nUser latest cards are {user_cards}, User latest score is {user_score}")
                else :
                    end = True

                while computer_score < 17 and computer_score != 0:
                    computer_cards.append(deal_card())
                    computer_score = calculate_score(computer_cards)
    #                 print(f"\nComputer latest cards are {computer_cards}, Computer score is {computer_score} ")


                print(f"\nYour final hand is {user_cards} and final score is {user_score}")
                print(f"computer final hand is {computer_cards} and final score is {computer_score}")

                if computer_score == 0:
                    return "\nYou lose!!! Computer has a blackjack"
                elif user_score == 0:
                    return "\nYou win!!! You have a blackjack"
                elif computer_score > 21:
                    return f"\nYou win.Computer score ({computer_score}) exceeds 21."
                elif user_score > 21:
                    return f"\nYou lose, Computer wins! Your score {user_score} exceeds 21"
                elif computer_score == user_score:
                    return "\nIts a draw!!!"
                elif computer_score > user_score:
                    return "\ncomputer wins. you lose"
                elif computer_score < user_score:
                    return "\nYou win"


    user_cards = []
    computer_cards = []


    for x in range (2):
        user_cards.append(deal_card())
        computer_cards.append(deal_card())


    user_score = calculate_score(user_cards)
    computer_score = calculate_score(computer_cards)

    print(f"User starting cards are {user_cards}, User starting score is {user_score}")
    print(f"first card of Computer is {computer_cards[0]}")


    blackjack = winner(computer_score, user_score)
    print(blackjack)

repeat = input("Do you want to play a game of blackjack? type 'Yes' or 'No': \n").lower()
while repeat == "yes":
    play()
    repeat = input("Do you want to play a game of blackjack? type 'Yes' or 'No': \n").lower()
# Out:
# Do you want to play a game of blackjack? type 'Yes' or 'No':
# yes
#
#     .------.            _     _            _    _            _
#     |A_  _ |.          | |   | |          | |  (_)          | |
#     |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
#     | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
#     |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
#     `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#           |  \/ K|                            _/ |
#           `------'                           |__/
#
# User starting cards are [3, 7], User starting score is 10
# first card of Computer is 10
#
# Do you want to draw another card? type 'yes' or 'no': yes
#
# User latest cards are [3, 7, 5], User latest score is 15
#
# Your final hand is [3, 7, 5] and final score is 15
# computer final hand is [10, 10] and final score is 20
#
# computer wins. you lose
# Do you want to play a game of blackjack? type 'Yes' or 'No':
# ...

# %% [markdown]
# ## This code is written after watching the video...so this is assisted code

# %% [markdown]
# This code is more efficient (less lines) and more understandable.
#
# This code is mostly bug free
#
# Note 1(bug 1)...removed... it only asks the user for more cards only once
#
# Note 2...if user and computer both go above 21, user wins... making the game slightly user tilted (even if both scores above 21 are equal)

# %%
logo = """
.------.            _     _            _    _            _    
|A_  _ |.          | |   | |          | |  (_)          | |   
|( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
| \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
|  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   < 
`-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\\
      |  \/ K|                            _/ |                
      `------'                           |__/           
"""
          
import random
cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]

def deal_card():
    return random.choice(cards)

def calculate_score(list_of_cards):
    """Takes a list of cards and returns the score(sum)"""
    
    if (10 in list_of_cards) and (11 in list_of_cards) and len(list_of_cards) == 2:    # alt. sum(list_of_cards) == 21 and len
        return 0    # 0 represents blackjack
    
    score = sum(list_of_cards)
    if (11 in list_of_cards) and score > 21:
        list_of_cards.remove(11)
        list_of_cards.append(1)
        score = sum(list_of_cards)
    return score

def compare(user_score,computer_score):
    if computer_score == 0:
        return f"You lose! Computer has got a blackjack "
    elif user_score == 0:
        return f"You Win! You have got a blackjack "
    elif computer_score == user_score:
        return "It's a Draw!"
    elif computer_score > 21:
        return f"You Win! Computer went above 21 i.e. ({computer_score})"
    elif user_score > 21:
        return f"You lose! you went above 21 i.e. ({user_score})"
    elif computer_score > user_score:
        return f"You lose! computer score({computer_score}) is more than your score({user_score})"
    elif computer_score < user_score:
        return f"You win! your score({user_score})) is more than computer score({computer_score})"

def play():
    user_cards = []
    computer_cards = []

    for x in range (2):
        user_cards.append(deal_card())
        computer_cards.append(deal_card())

    game_over = False
    while game_over == False:
        user_score = calculate_score(user_cards)
        computer_score = calculate_score(computer_cards)

        print(f"User current cards are :{user_cards} and  user current_score is :{user_score}")
        print(f"First card of computer is {computer_cards[0]}")

        # print(f"User score is {user_score}")
        # print(f"Computer score is {computer_score}")


        if user_score == 0 or computer_score == 0 or user_score >21:
            game_over = True
        else:
            one_more = input("\nDo you want to draw another card? type 'yes' or 'no': ").lower()
            if one_more =="yes":
                user_cards.append(deal_card())
    #             print(f"User current cards are {user_cards}")
    #             user_score = calculate_score(user_cards)
    #             print(f"User current score is {user_score}")
            else:
                game_over = True


    while computer_score < 17 and computer_score != 0:
        computer_cards.append(deal_card())
        computer_score = calculate_score(computer_cards)



    winner = compare(user_score,computer_score)
    print("\n")
    print(f"your final hand is {user_cards} and final score is {user_score}")
    print(f"computer final hand is {computer_cards} and final score is {computer_score}")
    print("\n")
    print(winner)

    

    
    
    
    
repeat = input("Do you want to play a game of blackjack? type 'Yes' or 'No': \n").lower()
while repeat == "yes":
    print(logo)
    play()
    repeat = input("Do you want to play a game of blackjack? type 'Yes' or 'No': \n").lower()
# Out:
# Do you want to play a game of blackjack? type 'Yes' or 'No':
# yes
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
# User current cards are :[5, 6] and  user current_score is :11
# First card of computer is 10
#
# Do you want to draw another card? type 'yes' or 'no': yes
# User current cards are :[5, 6, 10] and  user current_score is :21
# First card of computer is 10
#
# Do you want to draw another card? type 'yes' or 'no': no
#
#
# your final hand is [5, 6, 10] and final score is 21
# computer final hand is [10, 10] and final score is 20
#
#
# ...

# %% [markdown]
# own... non repetition

# %%
# own... non repetition
# unknown bug... sometines user cards gets updated when you type yes for more cards (not including all initial cards)
logo = """
.------.            _     _            _    _            _    
|A_  _ |.          | |   | |          | |  (_)          | |   
|( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
| \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
|  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   < 
`-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\\
      |  \/ K|                            _/ |                
      `------'                           |__/           
"""
          
print(logo)    
import random
cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]

def deal_card():
    return random.choice(cards)

def calculate_score(list_of_cards):
    """Takes a list of cards and returns the score(sum)"""
    
    if (10 in list_of_cards) and (11 in list_of_cards) and len(list_of_cards) == 2:    # alt. sum(list_of_cards) == 21 and len
        return 0    # 0 represents blackjack
    
    score = sum(list_of_cards)
    if (11 in list_of_cards) and score > 21:
        list_of_cards.remove(11)
        list_of_cards.append(1)
        score = sum(list_of_cards)
    return score


    
def winner(computer_score,user_score):
    end = False
    while not end:
        if computer_score == 0 or user_score > 21:
            end = True
            return "computer wins. you lose"
        if computer_score > 21 or user_score == 0:
            end = True
            return "You win"
        else:
            one_more = input("\nDo you want to draw another card? type 'yes' or 'no': ").lower()
            if one_more =="yes":
                user_cards.append(deal_card())
                user_score = calculate_score(user_cards)
                print(f"\nUser latest cards are {user_cards}, User latest score is {user_score}")
            else :
                end = True
            
            while computer_score < 17 and computer_score != 0:
                computer_cards.append(deal_card())
                computer_score = calculate_score(computer_cards)
#                 print(f"\nComputer latest cards are {computer_cards}, Computer score is {computer_score} ")

            
            print(f"\nYour final hand is {user_cards} and final score is {user_score}")
            print(f"computer final hand is {computer_cards} and final score is {computer_score}")
            
            if computer_score == 0:
                return "\nYou lose!!! Computer has a blackjack"
            elif user_score == 0:
                return "\nYou win!!! You have a blackjack"
            elif computer_score > 21:
                return f"\nYou win.Computer score ({computer_score}) exceeds 21."
            elif user_score > 21:
                return f"\nYou lose, Computer wins! Your score {user_score} exceeds 21"
            elif computer_score == user_score:
                return "\nIts a draw!!!"
            elif computer_score > user_score:
                return "\ncomputer wins. you lose"
            elif computer_score < user_score:
                return "\nYou win"
            

user_cards = []
computer_cards = []


for x in range (2):
    user_cards.append(deal_card())
    computer_cards.append(deal_card())


user_score = calculate_score(user_cards)
computer_score = calculate_score(computer_cards)

print(f"User starting cards are {user_cards}, User starting score is {user_score}")
print(f"first card of Computer is {computer_cards[0]}")


blackjack = winner(computer_score, user_score)
print(blackjack)
# Out:
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
# User starting cards are [7, 4], User starting score is 11
# first card of Computer is 10
#
# Do you want to draw another card? type 'yes' or 'no': yes
#
# User latest cards are [7, 4, 10], User latest score is 21
#
# Your final hand is [7, 4, 10] and final score is 21
# computer final hand is [10, 10] and final score is 20
#
# You win

# %%
# bug ... it only asks for more cards once
import random
cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]

def deal_card():
    return random.choice(cards)

def calculate_score(list_of_cards):
    if (10 in list_of_cards) and (11 in list_of_cards):
        return 0    # 0 represents blackjack
    
    score = sum(list_of_cards)
    if (11 in list_of_cards) and score > 21:
        list_of_cards.remove(11)
        list_of_cards.append(1)
        score = sum(list_of_cards)
    return score
user_cards = []
computer_cards = []

for x in range (2):
    user_cards.append(deal_card())
    computer_cards.append(deal_card())
    
# print(user_cards)
# print(computer_cards)




# print(calculate_score(user_cards))
# print(calculate_score(computer_cards))

user_score = calculate_score(user_cards)
computer_score = calculate_score(computer_cards)

def winner(computer_score,user_score):
    end = False
    while not end:
        if computer_score == 0 or user_score > 21:
            end = True
            return "computer wins. you lose"
        elif computer_score > 21 or user_score == 0:
            end = True
            return "You win"
        else:
            while computer_score < 17:
                computer_cards.append(deal_card)
                computer_score = calculate_score(computer_cards)
            one_more = input("Do you want to draw another card? type 'yes' or 'no': ").lower()
            if one_more =="yes":
                user_cards.append(deal_card())
                user_score = calculate_score(user_cards)
            else :
                end = True
            if computer_score == user_score:
                return "Its a draw!!!"
            elif computer_score > user_score:
                return "computer wins. you lose"
            elif computer_score < user_score:
                return "You win"

# %%
import random
cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]

def deal_card():
    return random.choice(cards)

def calculate_score(list_of_cards):
    if (10 in list_of_cards) and (11 in list_of_cards):
        return 0    # 0 represents blackjack
    
    score = sum(list_of_cards)
    if (11 in list_of_cards) and score > 21:
        list_of_cards.remove(11)
        list_of_cards.append(1)
        score = sum(list_of_cards)
    return score




def winner(computer,user):
    end = False
    while not end:
        if computer == 0 or user > 21:
            end = True
            return "computer wins. you lose"
        if computer > 21 or user == 0:
            end = True
            return "You win"
        else:
            while computer < 17:
                computer_cards.append(deal_card())
                print(f"Computer acrds are {computer_cards}")
                computer = calculate_score(computer_cards)
            one_more = input("Do you want to draw another card? type 'yes' or 'no': ").lower()
            if one_more =="yes":
                user_cards.append(deal_card())
                print(f"User cards are {user_cards}")
                user = calculate_score(user_cards)
            else :
                end = True
            if computer > 21:
                print(f"Computer score is {computer_score}")
                return "You win"
            elif user > 21:
                print(f"User score is {user_score}")
                return "computer wins. you lose"
            elif computer == user:
                return "Its a draw!!!"
            elif computer > user:
                return "computer wins. you lose"
            elif computer < user:
                return "You win"


            
user_cards = []
computer_cards = []

for x in range (2):
    user_cards.append(deal_card())
    computer_cards.append(deal_card())
    
print(f"User cards are {user_cards}")
print(f"Computer cards are {computer_cards}")


user_score = calculate_score(user_cards)
computer_score = calculate_score(computer_cards)

print(f"User score is {user_score}")
print(f"Computer score is {computer_score}")


blackjack = winner(computer = computer_score, user = user_score)
print(blackjack)
# Out:
# User cards are [3, 2]
# Computer cards are [10, 7]
# User score is 5
# Computer score is 17
# Do you want to draw another card? type 'yes' or 'no': yes
# User cards are [3, 2, 10]
# computer wins. you lose
