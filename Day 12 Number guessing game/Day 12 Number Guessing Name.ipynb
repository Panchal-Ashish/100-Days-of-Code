# %% [markdown]
# # Number guessing game

# %%
import random

    

# def compare(com,guess):
#     if com == guess:
        
    
    
def number_guessing_game():
    global lives
    while lives > 0:
        guess = int(input("Guess a number between 1 to 100: "))
        if guess == com:
            print("\n")
            print(f"You guessed the correct number({com})!!!\n You Win!!!")
            return
        elif guess > com:
            print("\n")
            print("Incorrect guess... Too high")
            lives = lives - 1
            print(f"you have {lives} lives left")
        elif guess < com:
            print("\n")
            print("Incorrect guess... Too low")
            lives = lives - 1
            print(f"you have {lives} lives left")
    if lives == 0:
        print("You exhausted all you lives")
        print(f"The correct number was {com} ")
        return

play = True
while play == True:
    com = random.randint(1,100)
    print("Welcome to number guessing game")
    print("I have choosen a number between 1 to 100")
    level = input("select difficulty level. type 'easy' for easy level and 'hard' for hard level:\n" ).lower()

    if level == "easy":
        lives = 10
        print("You have 10 attempts left!!!")
    elif level == "hard":
        lives = 5
        print("You have 5 attempts left!!!")
    else:
        print("incorrect difficulty level input")    
    print("\n")
    number_guessing_game()
    again = input("Do you want to play again? type 'yes' or 'no': \n").lower() 
    if again == "yes":
        play = True
    else:
        play = False
    
    
    
#     have_life = True
    
#     while have_life == true:
#         guess = int(input("Guess a number between 1 to 100: "))
#         result = compare(com,guess)
# Out:
# Welcome to number guessing game
# I have choosen a number between 1 to 100
# select difficulty level. type 'easy' for easy level and 'hard' for hard level:easy
# You have 10 attempts left!!!
#
#
# Guess a number between 1 to 100: 57
#
#
# Incorrect guess... Too low
# you have 9 lives left
# Guess a number between 1 to 100: 75
#
#
# Incorrect guess... Too high
# you have 8 lives left
# Guess a number between 1 to 100: 65
#
#
# Incorrect guess... Too low
# you have 7 lives left
# Guess a number between 1 to 100: 74
#
#
# Incorrect guess... Too high
# you have 6 lives left
# Guess a number between 1 to 100: 73
#
#
# Incorrect guess... Too high
# you have 5 lives left
# Guess a number between 1 to 100: 70
#
#
# Incorrect guess... Too high
# you have 4 lives left
# Guess a number between 1 to 100: 66
#
#
# Incorrect guess... Too low
# you have 3 lives left
# Guess a number between 1 to 100: 68
#
#
# Incorrect guess... Too high
# you have 2 lives left
# Guess a number between 1 to 100: 69
# ...
